# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from diffusers import FluxKontextPipeline
from diffusers.utils import load_image
import sys
sys.path.append('/home/svu/e1352224/workspace/kv-cache/spotedit')
sys.path.append('/home/svu/e1352224/workspace/kv-cache/spotedit/FLUX_kontext')
from FLUX_kontext import generate, SpotEditConfig
from flux_spot_ultis import seed_everything

# %%
pipe = FluxKontextPipeline.from_pretrained('black-forest-labs/FLUX.1-Kontext-dev', torch_dtype=torch.bfloat16).to('cuda')
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers

# %%
image = load_image('/home/svu/e1352224/workspace/kv-cache/spotedit/asset/dog.jpg')
image = image.resize((1024, 1024))

# %%
config = SpotEditConfig(threshold=1, dilation_radius=0,reset_steps=[9,18,27,36,45])

# %%
import pickle
with open('/home/svu/e1352224/scratch/spotedit_results/new_dataset/IMGedit/IMGedit_success.pkl', 'rb') as f:
    data = pickle.load(f)
for sample in data:
    if sample['sample_id'] == '1068':
        image = sample['image_pil']
        edit_prompt = sample['edit_prompt']

# %%
seed_everything(42)
res = generate(
    pipe,
    image = image,
    prompt = edit_prompt,
    config = config,
    num_inference_steps=50,
    guidance_scale=7.5,
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
res.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
